# %% [markdown]
# # Input setup

# %%
import torch
import torchvision
import torchvision.transforms as T
import cv2
import numpy as np

cap = cv2.VideoCapture('./testVideos/vid2.mp4')
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
print(width,height,fps)

# Create a video writer object to save the output video in MP4 format
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('./outputs/vid2RCNN_Sort.mp4', fourcc, fps, (width, height))
# Out:
# 1280 720 29

# %% [markdown]
# # FasterRCNN

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
transform = T.Compose([T.ToTensor(), T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# weights (COCOv1 dataset trained)
weights=torchvision.models.detection.faster_rcnn.FasterRCNN_ResNet50_FPN_V2_Weights.DEFAULT
# model
model = torchvision.models.detection.fasterrcnn_resnet50_fpn_v2(weights)
model = model.to(device)
model.eval()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): FastRCNNConvFCHead(
#       (0): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (1): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (2): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (3): Conv2dNormActivation(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (4): Flatten(start_dim=1, end_dim=-1)
#       (5): Linear(in_features=12544, out_features=1024, bias=True)
#       (6): ReLU(inplace=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %% [markdown]
# # Sort

# %%
from sort.sort import Sort

# Set up the SORT tracker
tracker = Sort(max_age=10000)

# %% [markdown]
# # Detection and Display

# %%
import time
start_time = time.time()
num_frames = 0

ids = []
while(cap.isOpened()):
      
# Capture frame-by-frame
    ret, frame = cap.read()
    if ret == True:
        # Increment the frame count
        num_frames += 1
        # Calculate fps
        elapsed_time = time.time() - start_time
        fps = num_frames / elapsed_time
        # Display the fps
        cv2.putText(frame, f"FPS: {round(fps, 2)}", (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        
        #detecting any object using FasterRCNN
        img = transform(frame).to(device)
        with torch.no_grad():
            result = model([img])[0]

        totaldetections = len(np.array(result['boxes'].to('cpu')))

        #converting output to sort input
        boxes = []
        for i in range(totaldetections):
            label = np.array(result['labels'].to('cpu'))[i]
            score = np.array(result['scores'].to('cpu'))[i]
            bbox = np.array(result['boxes'].to('cpu'))[i]
            # if(result['name'][i] == 'car' or result['name'][i] == 'truck' or result['name'][i] == 'motorcycle' or result['name'][i] == 'bicycle'):
            if(label == 3 or label == 8):
                bbox = [bbox[0],bbox[1],bbox[2],bbox[3]]
                boxes.append(bbox)

        boxes = np.array(boxes)

        # indices = preprocessing.non_max_suppression(boxes, nms_max_overlap,scores)
        # detections = [detections[i] for i in indices]

        # Use SORT to track the cars across frames
        track_bbs_ids = tracker.update(boxes)

        for track in track_bbs_ids:
            xmin, ymin, xmax, ymax, track_id = track
            ids.append(track_id)
            cv2.rectangle(frame, (int(xmin), int(ymin)), (int(xmax), int(ymax)), (255,0,0), 2)
            cv2.putText(frame, str(track_id), (int(xmin), int(ymin) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)


        cv2.putText(frame, "Total Cars: "+str(len(set(ids))), (10,10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,0,0), 2)
        cv2.imshow('Frame', frame)
        # write frame to output video
        out.write(frame)
            

    # Press Q on keyboard to exit
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break
  
# Break the loop
    else:
        break
# Out:
# 1   HIToolbox                           0x00000001a40ced4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001a3fa8230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001a3fac380 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 104
# 4   HIToolbox                           0x00000001a3f0c4c0 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1092
# 5   HIToolbox                           0x00000001a3f0b940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 6   HIToolbox                           0x00000001a3f0b7d0 SendEventToEventTargetWithOptions + 44
# 7   HIToolbox                           0x00000001a3f4b9cc _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 472
# 8   HIToolbox                           0x00000001a3f0c968 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2284
# 9   HIToolbox                           0x00000001a3f0b940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 10  HIToolbox                           0x00000001a3f21bb8 SendEventToEventTarget + 40
# 11  AppKit                              0x000000019dc7dda0 _NXFinishActivation + 168
# 12  AppKit                              0x000000019e2c4f50 -[NSWindow(NSWindow_Theme) _prepareToRestoreRegularFromDock:forceActivation:wantsToBeKey:] + 244
# 13  AppKit                              0x000000019e2c50a0 -[NSWindow(NSWindow_Theme) _prepareToRestoreFromDock:forceActivation:wantsToBeKey:] + 112
# 14  AppKit                              0x000000019e2c4dec -[NSWindow(NSWindow_Theme) _doRestoreComingFromDock:forceActivation:wantsToBeKey:] + 28
# 15  AppKit                              0x000000019dc0a828 _NSCGSDockMessageReceive + 732
# 16  HIToolbox                           0x00000001a3f5b2e4 _ZL12DockCallbackjjPvS_ + 1528
# 17  HIServices                          0x000000019ffea8d4 _DCXSelectWindow + 40
# 18  HIServices                          0x000000019ffea880 _XSelectWindow + 56
# 19  HIServices                          0x000000019ffdbba8 mshMIGPerform + 204
# 20  CoreFoundation                      0x000000019a855f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 21  CoreFoundation                      0x000000019a855eb8 __CFRunLoopDoSource1 + 520
# 22  CoreFoundation                      0x000000019a8548a4 __CFRunLoopRun + 2264
# 23  CoreFoundation                      0x000000019a853878 CFRunLoopRunSpecific + 612
# 24  HIToolbox                           0x00000001a3f33fa0 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00000001a3f33de4 ReceiveNextEventCommon + 672
# 26  HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 27  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 28  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 29  cv2.abi3.so                         0x000000017d698ad0 cvWaitKey + 344
# 30  cv2.abi3.so                         0x000000017d692c08 _ZN2cv9waitKeyExEi + 168
# 31  cv2.abi3.so                         0x000000017d692d00 _ZN2cv7waitKeyEi + 48
# 32  cv2.abi3.so                         0x000000017c9f914c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.8                           0x00000001008583e0 cfunction_call_varargs + 288
# 34  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 35  python3.8                           0x0000000100944158 call_function + 612
# 36  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 37  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 38  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 39  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 40  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 41  python3.8                           0x00000001009440c0 call_function + 460
# 42  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 43  python3.8                           0x000000010086e254 gen_send_ex + 288
# 44  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 45  python3.8                           0x000000010086e254 gen_send_ex + 288
# 46  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 47  python3.8                           0x000000010086e254 gen_send_ex + 288
# 48  python3.8                           0x0000000100865444 method_vectorcall_O + 448
# 49  python3.8                           0x00000001009440c0 call_function + 460
# 50  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 51  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 52  python3.8                           0x00000001009440c0 call_function + 460
# 53  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 54  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 55  python3.8                           0x00000001009440c0 call_function + 460
# 56  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 57  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 58  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 59  python3.8                           0x000000010085bea4 method_vectorcall + 520
# 60  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 61  python3.8                           0x0000000100940af0 _PyEval_EvalFrameDefault + 27868
# 62  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 63  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 64  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 65  python3.8                           0x00000001009440c0 call_function + 460
# 66  python3.8                           0x0000000100940934 _PyEval_EvalFrameDefault + 27424
# 67  python3.8                           0x000000010086e254 gen_send_ex + 288
# 68  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 69  python3.8                           0x000000010086e254 gen_send_ex + 288
# 70  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 71  python3.8                           0x000000010086e254 gen_send_ex + 288
# 72  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 73  python3.8                           0x000000010086e254 gen_send_ex + 288
# 74  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 75  python3.8                           0x000000010086e254 gen_send_ex + 288
# 76  _asyncio.cpython-38-darwin.so       0x00000001032bfdb4 task_step + 680
# 77  _asyncio.cpython-38-darwin.so       0x00000001032bf940 TaskWakeupMethWrapper_call + 248
# 78  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 79  python3.8                           0x0000000100958cd8 context_run + 328
# 80  python3.8                           0x00000001008a56ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 81  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 82  python3.8                           0x0000000100940cb4 _PyEval_EvalFrameDefault + 28320
# 83  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 84  python3.8                           0x00000001009440c0 call_function + 460
# 85  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 86  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 87  python3.8                           0x00000001009440c0 call_function + 460
# 88  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 89  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 90  python3.8                           0x00000001009440c0 call_function + 460
# 91  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 92  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 93  python3.8                           0x00000001009440c0 call_function + 460
# 94  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 95  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 96  python3.8                           0x00000001009440c0 call_function + 460
# 97  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 98  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 99  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 100 python3.8                           0x000000010085bd38 method_vectorcall + 156
# 101 python3.8                           0x00000001009440c0 call_function + 460
# 102 python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 103 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 105 python3.8                           0x0000000100934fa0 builtin_exec + 900
# 106 python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 107 python3.8                           0x00000001009440c0 call_function + 460
# 108 python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 109 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 110 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 111 python3.8                           0x00000001009440c0 call_function + 460
# 112 python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 113 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 114 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 115 python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 116 python3.8                           0x00000001009ad1b8 pymain_run_module + 240
# 117 python3.8                           0x00000001009ac928 Py_RunMain + 1616
# 118 python3.8                           0x00000001009adc50 pymain_main + 1220
# 119 python3.8                           0x0000000100832084 main + 56
# 120 dyld                                0x000000019a44be50 start + 2544
# 1   HIToolbox                           0x00000001a3fa85c8 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 120
# 2   HIToolbox                           0x00000001a3f4b27c SetMenuBarObscured + 224
# 3   HIToolbox                           0x00000001a3f4aee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 4   HIToolbox                           0x00000001a3f44fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 5   HIToolbox                           0x00000001a3f0bcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001a3f4496c AcquireEventFromQueue + 432
# 7   HIToolbox                           0x00000001a3f33c84 ReceiveNextEventCommon + 320
# 8   HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 9   AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 10  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 11  cv2.abi3.so                         0x000000017d698ad0 cvWaitKey + 344
# 12  cv2.abi3.so                         0x000000017d692c08 _ZN2cv9waitKeyExEi + 168
# 13  cv2.abi3.so                         0x000000017d692d00 _ZN2cv7waitKeyEi + 48
# 14  cv2.abi3.so                         0x000000017c9f914c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 15  python3.8                           0x00000001008583e0 cfunction_call_varargs + 288
# 16  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 17  python3.8                           0x0000000100944158 call_function + 612
# 18  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 19  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 20  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 21  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 22  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 23  python3.8                           0x00000001009440c0 call_function + 460
# 24  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 25  python3.8                           0x000000010086e254 gen_send_ex + 288
# 26  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 27  python3.8                           0x000000010086e254 gen_send_ex + 288
# 28  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 29  python3.8                           0x000000010086e254 gen_send_ex + 288
# 30  python3.8                           0x0000000100865444 method_vectorcall_O + 448
# 31  python3.8                           0x00000001009440c0 call_function + 460
# 32  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 33  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 34  python3.8                           0x00000001009440c0 call_function + 460
# 35  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 36  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 37  python3.8                           0x00000001009440c0 call_function + 460
# 38  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 39  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 40  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 41  python3.8                           0x000000010085bea4 method_vectorcall + 520
# 42  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 43  python3.8                           0x0000000100940af0 _PyEval_EvalFrameDefault + 27868
# 44  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 45  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 46  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 47  python3.8                           0x00000001009440c0 call_function + 460
# 48  python3.8                           0x0000000100940934 _PyEval_EvalFrameDefault + 27424
# 49  python3.8                           0x000000010086e254 gen_send_ex + 288
# 50  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 51  python3.8                           0x000000010086e254 gen_send_ex + 288
# 52  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 53  python3.8                           0x000000010086e254 gen_send_ex + 288
# 54  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 55  python3.8                           0x000000010086e254 gen_send_ex + 288
# 56  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 57  python3.8                           0x000000010086e254 gen_send_ex + 288
# 58  _asyncio.cpython-38-darwin.so       0x00000001032bfdb4 task_step + 680
# 59  _asyncio.cpython-38-darwin.so       0x00000001032bf940 TaskWakeupMethWrapper_call + 248
# 60  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 61  python3.8                           0x0000000100958cd8 context_run + 328
# 62  python3.8                           0x00000001008a56ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 63  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 64  python3.8                           0x0000000100940cb4 _PyEval_EvalFrameDefault + 28320
# 65  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 66  python3.8                           0x00000001009440c0 call_function + 460
# 67  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 68  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 69  python3.8                           0x00000001009440c0 call_function + 460
# 70  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 71  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 72  python3.8                           0x00000001009440c0 call_function + 460
# 73  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 74  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 75  python3.8                           0x00000001009440c0 call_function + 460
# 76  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 77  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 78  python3.8                           0x00000001009440c0 call_function + 460
# 79  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 80  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 81  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 82  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 83  python3.8                           0x00000001009440c0 call_function + 460
# 84  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 85  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 86  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 87  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 88  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 89  python3.8                           0x00000001009440c0 call_function + 460
# 90  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 91  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 92  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 93  python3.8                           0x00000001009440c0 call_function + 460
# 94  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 95  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 96  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 97  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 98  python3.8                           0x00000001009ad1b8 pymain_run_module + 240
# 99  python3.8                           0x00000001009ac928 Py_RunMain + 1616
# 100 python3.8                           0x00000001009adc50 pymain_main + 1220
# 101 python3.8                           0x0000000100832084 main + 56
# 102 dyld                                0x000000019a44be50 start + 2544
# 2023-03-22 23:45:05.534 python[7934:78267] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_bundleIdentifierWithReply:) block performed very slowly (3.83 secs).
# 1   HIToolbox                           0x00000001a40ced4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001a3fa8230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001a3f1530c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001a3fa88a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001a3f0bcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001a3f3fbb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001a3f41340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001a3f40c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001a3f40ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x000000019a885410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x000000019a855f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x000000019a855eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x000000019a8548a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x000000019a853878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001a3f33fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001a3f33c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 19  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x000000017d698ad0 cvWaitKey + 344
# 21  cv2.abi3.so                         0x000000017d692c08 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x000000017d692d00 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x000000017c9f914c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.8                           0x00000001008583e0 cfunction_call_varargs + 288
# 25  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 26  python3.8                           0x0000000100944158 call_function + 612
# 27  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 28  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 29  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 30  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 31  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 32  python3.8                           0x00000001009440c0 call_function + 460
# 33  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 34  python3.8                           0x000000010086e254 gen_send_ex + 288
# 35  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 36  python3.8                           0x000000010086e254 gen_send_ex + 288
# 37  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 38  python3.8                           0x000000010086e254 gen_send_ex + 288
# 39  python3.8                           0x0000000100865444 method_vectorcall_O + 448
# 40  python3.8                           0x00000001009440c0 call_function + 460
# 41  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 42  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 43  python3.8                           0x00000001009440c0 call_function + 460
# 44  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 45  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 46  python3.8                           0x00000001009440c0 call_function + 460
# 47  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 48  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 49  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 50  python3.8                           0x000000010085bea4 method_vectorcall + 520
# 51  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 52  python3.8                           0x0000000100940af0 _PyEval_EvalFrameDefault + 27868
# 53  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 54  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 55  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 56  python3.8                           0x00000001009440c0 call_function + 460
# 57  python3.8                           0x0000000100940934 _PyEval_EvalFrameDefault + 27424
# 58  python3.8                           0x000000010086e254 gen_send_ex + 288
# 59  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 60  python3.8                           0x000000010086e254 gen_send_ex + 288
# 61  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 62  python3.8                           0x000000010086e254 gen_send_ex + 288
# 63  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 64  python3.8                           0x000000010086e254 gen_send_ex + 288
# 65  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 66  python3.8                           0x000000010086e254 gen_send_ex + 288
# 67  _asyncio.cpython-38-darwin.so       0x00000001032bfdb4 task_step + 680
# 68  _asyncio.cpython-38-darwin.so       0x00000001032bf940 TaskWakeupMethWrapper_call + 248
# 69  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 70  python3.8                           0x0000000100958cd8 context_run + 328
# 71  python3.8                           0x00000001008a56ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 72  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 73  python3.8                           0x0000000100940cb4 _PyEval_EvalFrameDefault + 28320
# 74  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 75  python3.8                           0x00000001009440c0 call_function + 460
# 76  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 77  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 78  python3.8                           0x00000001009440c0 call_function + 460
# 79  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 80  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 81  python3.8                           0x00000001009440c0 call_function + 460
# 82  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 83  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 84  python3.8                           0x00000001009440c0 call_function + 460
# 85  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 86  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 87  python3.8                           0x00000001009440c0 call_function + 460
# 88  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 89  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 90  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 91  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 92  python3.8                           0x00000001009440c0 call_function + 460
# 93  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 94  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 95  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 96  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 97  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 98  python3.8                           0x00000001009440c0 call_function + 460
# 99  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 100 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 101 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 102 python3.8                           0x00000001009440c0 call_function + 460
# 103 python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 104 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 105 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 106 python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 107 python3.8                           0x00000001009ad1b8 pymain_run_module + 240
# 108 python3.8                           0x00000001009ac928 Py_RunMain + 1616
# 109 python3.8                           0x00000001009adc50 pymain_main + 1220
# 110 python3.8                           0x0000000100832084 main + 56
# 111 dyld                                0x000000019a44be50 start + 2544
# 1   HIToolbox                           0x00000001a40ced4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x00000001a3fa8230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x00000001a3f1530c _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 72
# 4   HIToolbox                           0x00000001a3fa88a0 _ZN15MenuBarInstance20AutoShowHideObserverEjP14OpaqueEventRefPv + 216
# 5   HIToolbox                           0x00000001a3f0bcd0 _NotifyEventLoopObservers + 176
# 6   HIToolbox                           0x00000001a3f3fbb0 PostEventToQueueInternal + 696
# 7   HIToolbox                           0x00000001a3f41340 _ZL29CreateAndPostEventWithCGEventP9__CGEventjhP17__CFMachPortBoost + 460
# 8   HIToolbox                           0x00000001a3f40c44 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 296
# 9   HIToolbox                           0x00000001a3f40ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 10  CoreFoundation                      0x000000019a885410 __CFMachPortPerform + 260
# 11  CoreFoundation                      0x000000019a855f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 12  CoreFoundation                      0x000000019a855eb8 __CFRunLoopDoSource1 + 520
# 13  CoreFoundation                      0x000000019a8548a4 __CFRunLoopRun + 2264
# 14  CoreFoundation                      0x000000019a853878 CFRunLoopRunSpecific + 612
# 15  HIToolbox                           0x00000001a3f33fa0 RunCurrentEventLoopInMode + 292
# 16  HIToolbox                           0x00000001a3f33c30 ReceiveNextEventCommon + 236
# 17  HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 18  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 19  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 20  cv2.abi3.so                         0x000000017d698ad0 cvWaitKey + 344
# 21  cv2.abi3.so                         0x000000017d692c08 _ZN2cv9waitKeyExEi + 168
# 22  cv2.abi3.so                         0x000000017d692d00 _ZN2cv7waitKeyEi + 48
# 23  cv2.abi3.so                         0x000000017c9f914c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 24  python3.8                           0x00000001008583e0 cfunction_call_varargs + 288
# 25  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 26  python3.8                           0x0000000100944158 call_function + 612
# 27  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 28  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 29  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 30  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 31  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 32  python3.8                           0x00000001009440c0 call_function + 460
# 33  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 34  python3.8                           0x000000010086e254 gen_send_ex + 288
# 35  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 36  python3.8                           0x000000010086e254 gen_send_ex + 288
# 37  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 38  python3.8                           0x000000010086e254 gen_send_ex + 288
# 39  python3.8                           0x0000000100865444 method_vectorcall_O + 448
# 40  python3.8                           0x00000001009440c0 call_function + 460
# 41  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 42  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 43  python3.8                           0x00000001009440c0 call_function + 460
# 44  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 45  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 46  python3.8                           0x00000001009440c0 call_function + 460
# 47  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 48  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 49  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 50  python3.8                           0x000000010085bea4 method_vectorcall + 520
# 51  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 52  python3.8                           0x0000000100940af0 _PyEval_EvalFrameDefault + 27868
# 53  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 54  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 55  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 56  python3.8                           0x00000001009440c0 call_function + 460
# 57  python3.8                           0x0000000100940934 _PyEval_EvalFrameDefault + 27424
# 58  python3.8                           0x000000010086e254 gen_send_ex + 288
# 59  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 60  python3.8                           0x000000010086e254 gen_send_ex + 288
# 61  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 62  python3.8                           0x000000010086e254 gen_send_ex + 288
# 63  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 64  python3.8                           0x000000010086e254 gen_send_ex + 288
# 65  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 66  python3.8                           0x000000010086e254 gen_send_ex + 288
# 67  _asyncio.cpython-38-darwin.so       0x00000001032bfdb4 task_step + 680
# 68  _asyncio.cpython-38-darwin.so       0x00000001032bf940 TaskWakeupMethWrapper_call + 248
# 69  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 70  python3.8                           0x0000000100958cd8 context_run + 328
# 71  python3.8                           0x00000001008a56ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 72  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 73  python3.8                           0x0000000100940cb4 _PyEval_EvalFrameDefault + 28320
# 74  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 75  python3.8                           0x00000001009440c0 call_function + 460
# 76  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 77  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 78  python3.8                           0x00000001009440c0 call_function + 460
# 79  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 80  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 81  python3.8                           0x00000001009440c0 call_function + 460
# 82  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 83  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 84  python3.8                           0x00000001009440c0 call_function + 460
# 85  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 86  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 87  python3.8                           0x00000001009440c0 call_function + 460
# 88  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 89  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 90  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 91  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 92  python3.8                           0x00000001009440c0 call_function + 460
# 93  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 94  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 95  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 96  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 97  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 98  python3.8                           0x00000001009440c0 call_function + 460
# 99  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 100 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 101 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 102 python3.8                           0x00000001009440c0 call_function + 460
# 103 python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 104 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 105 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 106 python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 107 python3.8                           0x00000001009ad1b8 pymain_run_module + 240
# 108 python3.8                           0x00000001009ac928 Py_RunMain + 1616
# 109 python3.8                           0x00000001009adc50 pymain_main + 1220
# 110 python3.8                           0x0000000100832084 main + 56
# 111 dyld                                0x000000019a44be50 start + 2544
# 1   HIToolbox                           0x00000001a3f3390c _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 44
# 2   HIToolbox                           0x00000001a3f72478 _ZL17BroadcastInternaljPvh + 184
# 3   SkyLight                            0x000000019f485214 _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 896
# 4   SkyLight                            0x000000019f483e10 CGSSnarfAndDispatchDatagrams + 808
# 5   SkyLight                            0x000000019f7aba9c SLSGetNextEventRecordInternal + 344
# 6   SkyLight                            0x000000019f5acfb0 SLEventCreateNextEvent + 16
# 7   HIToolbox                           0x00000001a3f40b58 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 60
# 8   HIToolbox                           0x00000001a3f40ae0 _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 60
# 9   CoreFoundation                      0x000000019a885410 __CFMachPortPerform + 260
# 10  CoreFoundation                      0x000000019a855f98 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 60
# 11  CoreFoundation                      0x000000019a855eb8 __CFRunLoopDoSource1 + 520
# 12  CoreFoundation                      0x000000019a8548a4 __CFRunLoopRun + 2264
# 13  CoreFoundation                      0x000000019a853878 CFRunLoopRunSpecific + 612
# 14  HIToolbox                           0x00000001a3f33fa0 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00000001a3f33c30 ReceiveNextEventCommon + 236
# 16  HIToolbox                           0x00000001a3f33b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 17  AppKit                              0x000000019dad984c _DPSNextEvent + 632
# 18  AppKit                              0x000000019dad89dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 19  cv2.abi3.so                         0x000000017d698ad0 cvWaitKey + 344
# 20  cv2.abi3.so                         0x000000017d692c08 _ZN2cv9waitKeyExEi + 168
# 21  cv2.abi3.so                         0x000000017d692d00 _ZN2cv7waitKeyEi + 48
# 22  cv2.abi3.so                         0x000000017c9f914c _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.8                           0x00000001008583e0 cfunction_call_varargs + 288
# 24  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 25  python3.8                           0x0000000100944158 call_function + 612
# 26  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 27  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 28  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 29  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 30  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 31  python3.8                           0x00000001009440c0 call_function + 460
# 32  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 33  python3.8                           0x000000010086e254 gen_send_ex + 288
# 34  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 35  python3.8                           0x000000010086e254 gen_send_ex + 288
# 36  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 37  python3.8                           0x000000010086e254 gen_send_ex + 288
# 38  python3.8                           0x0000000100865444 method_vectorcall_O + 448
# 39  python3.8                           0x00000001009440c0 call_function + 460
# 40  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 41  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 42  python3.8                           0x00000001009440c0 call_function + 460
# 43  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 44  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 45  python3.8                           0x00000001009440c0 call_function + 460
# 46  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 47  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 48  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 49  python3.8                           0x000000010085bea4 method_vectorcall + 520
# 50  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 51  python3.8                           0x0000000100940af0 _PyEval_EvalFrameDefault + 27868
# 52  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 53  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 54  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 55  python3.8                           0x00000001009440c0 call_function + 460
# 56  python3.8                           0x0000000100940934 _PyEval_EvalFrameDefault + 27424
# 57  python3.8                           0x000000010086e254 gen_send_ex + 288
# 58  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 59  python3.8                           0x000000010086e254 gen_send_ex + 288
# 60  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 61  python3.8                           0x000000010086e254 gen_send_ex + 288
# 62  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 63  python3.8                           0x000000010086e254 gen_send_ex + 288
# 64  python3.8                           0x000000010093c8b4 _PyEval_EvalFrameDefault + 10912
# 65  python3.8                           0x000000010086e254 gen_send_ex + 288
# 66  _asyncio.cpython-38-darwin.so       0x00000001032bfdb4 task_step + 680
# 67  _asyncio.cpython-38-darwin.so       0x00000001032bf940 TaskWakeupMethWrapper_call + 248
# 68  python3.8                           0x0000000100857af0 _PyObject_MakeTpCall + 744
# 69  python3.8                           0x0000000100958cd8 context_run + 328
# 70  python3.8                           0x00000001008a56ec cfunction_vectorcall_FASTCALL_KEYWORDS + 228
# 71  python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 72  python3.8                           0x0000000100940cb4 _PyEval_EvalFrameDefault + 28320
# 73  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 74  python3.8                           0x00000001009440c0 call_function + 460
# 75  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 76  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 77  python3.8                           0x00000001009440c0 call_function + 460
# 78  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 79  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 80  python3.8                           0x00000001009440c0 call_function + 460
# 81  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 82  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 83  python3.8                           0x00000001009440c0 call_function + 460
# 84  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 85  python3.8                           0x00000001008587b4 function_code_fastcall + 128
# 86  python3.8                           0x00000001009440c0 call_function + 460
# 87  python3.8                           0x0000000100940818 _PyEval_EvalFrameDefault + 27140
# 88  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 89  python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 90  python3.8                           0x000000010085bd38 method_vectorcall + 156
# 91  python3.8                           0x00000001009440c0 call_function + 460
# 92  python3.8                           0x000000010094083c _PyEval_EvalFrameDefault + 27176
# 93  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 94  python3.8                           0x0000000100938c30 PyEval_EvalCode + 60
# 95  python3.8                           0x0000000100934fa0 builtin_exec + 900
# 96  python3.8                           0x00000001008a55c0 cfunction_vectorcall_FASTCALL + 284
# 97  python3.8                           0x00000001009440c0 call_function + 460
# 98  python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 99  python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 100 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 101 python3.8                           0x00000001009440c0 call_function + 460
# 102 python3.8                           0x00000001009408b8 _PyEval_EvalFrameDefault + 27300
# 103 python3.8                           0x00000001009397fc _PyEval_EvalCodeWithName + 3008
# 104 python3.8                           0x0000000100858918 _PyFunction_Vectorcall + 208
# 105 python3.8                           0x0000000100857fd8 PyVectorcall_Call + 120
# 106 python3.8                           0x00000001009ad1b8 pymain_run_module + 240
# 107 python3.8                           0x00000001009ac928 Py_RunMain + 1616
# 108 python3.8                           0x00000001009adc50 pymain_main + 1220
# 109 python3.8                           0x0000000100832084 main + 56
# 110 dyld                                0x000000019a44be50 start + 2544
